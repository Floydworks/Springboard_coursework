# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties.shape
# Out:
# (322, 49)

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#transpose properties so dates are at top, boroughs are rows
propertiesT = properties.transpose()
print(propertiesT.shape)
propertiesT.head()
# Out:
# (49, 322)
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
#name first row[0] (dates) as the header/column names
propertiesT.columns = propertiesT.iloc[0]
propertiesT.head()
# Out:
# Unnamed: 0                NaT           1995-01-01           1995-02-01  \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
# Unnamed: 0                   1995-03-01           1995-04-01  \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
# Unnamed: 0                   1995-05-01           1995-06-01  \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# delete first row which is now a duplicate of header
propertiesT = propertiesT[1:]
propertiesT.head()
# Out:
# Unnamed: 0                NaT   1995-01-01   1995-02-01   1995-03-01  \
# City of London      E09000001  91448.98487  82202.77314  79120.70256
# Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# Barnet              E09000003  93284.51832  93190.16963  92247.52435
# Bexley              E09000004  64958.09036  64787.92069  64367.49344
# Brent               E09000005  71306.56698  72022.26197  72015.76274
#
# Unnamed: 0           1995-04-01   1995-05-01   1995-06-01   1995-07-01  \
# City of London      77101.20804  84409.14932  94900.51244  110128.0423
# Barking & Dagenham  53133.50526  53042.24852  53700.34831  52113.12157
# Barnet              90762.87492  90258.00033  90107.23471  91441.24768
# Bexley              64277.66881  63997.13588  64252.32335  63722.70055
# Brent               72965.63094  73704.04743  74310.48167  74127.03788
#
# Unnamed: 0           1995-08-01   1995-09-01  ...   2020-12-01   2021-01-01  \
# ...

# %%
propertiesT.index
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Unnamed: 34', 'Inner London', 'Outer London', 'Unnamed: 37',
#        'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
propertiesT.reset_index()
# Out:
# Unnamed: 0                 index        NaN 1995-01-01 00:00:00  \
# 0                 City of London  E09000001         91448.98487
# 1             Barking & Dagenham  E09000002          50460.2266
# 2                         Barnet  E09000003         93284.51832
# 3                         Bexley  E09000004         64958.09036
# 4                          Brent  E09000005         71306.56698
# 5                        Bromley  E09000006         81671.47692
# 6                         Camden  E09000007         120932.8881
# 7                        Croydon  E09000008         69158.16225
# 8                         Ealing  E09000009         79885.89069
# 9                        Enfield  E09000010         72514.69096
# 10                     Greenwich  E09000011         62300.10169
# 11                       Hackney  E09000012         61296.52637
# 12          Hammersmith & Fulham  E09000013         124902.8602
# 13                      Haringey  E09000014         76287.56947
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#set index to left
propertiesT.reset_index(inplace=True)

# %%
# rename the index column and first two data columns
propertiesT = propertiesT.rename(columns = {'index':'borough', pd.NaT: 'ID'})

# %%
propertiesT.head()
#print(properties.shape)
#print(list(properties.columns))
# Out:
# Unnamed: 0             borough         ID 1995-01-01 00:00:00  \
# 0               City of London  E09000001         91448.98487
# 1           Barking & Dagenham  E09000002          50460.2266
# 2                       Barnet  E09000003         93284.51832
# 3                       Bexley  E09000004         64958.09036
# 4                        Brent  E09000005         71306.56698
#
# Unnamed: 0 1995-02-01 00:00:00 1995-03-01 00:00:00 1995-04-01 00:00:00  \
# 0                  82202.77314         79120.70256         77101.20804
# 1                  51085.77983         51268.96956         53133.50526
# 2                  93190.16963         92247.52435         90762.87492
# 3                  64787.92069         64367.49344         64277.66881
# 4                  72022.26197         72015.76274         72965.63094
#
# Unnamed: 0 1995-05-01 00:00:00 1995-06-01 00:00:00 1995-07-01 00:00:00  \
# 0                  84409.14932         94900.51244         110128.0423
# ...

# %%
#select only rows for each borough, and all columns
propertiesT = propertiesT.iloc[0:33, 0:]

#print(properties.iloc[0:, 0:3])
print(propertiesT.shape)
# Out:
# (33, 323)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_long = pd.melt(propertiesT, id_vars=['borough','ID'],
             var_name='date', value_name='avg_price')

# %%
print(list(properties_long.columns))
print(properties_long.shape)
properties_long.head(35)
# Out:
# ['borough', 'ID', 'date', 'avg_price']
# (10593, 4)
#                  borough         ID       date    avg_price
# 0         City of London  E09000001 1995-01-01  91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2                 Barnet  E09000003 1995-01-01  93284.51832
# 3                 Bexley  E09000004 1995-01-01  64958.09036
# 4                  Brent  E09000005 1995-01-01  71306.56698
# 5                Bromley  E09000006 1995-01-01  81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.8881
# 7                Croydon  E09000008 1995-01-01  69158.16225
# 8                 Ealing  E09000009 1995-01-01  79885.89069
# 9                Enfield  E09000010 1995-01-01  72514.69096
# 10             Greenwich  E09000011 1995-01-01  62300.10169
# 11               Hackney  E09000012 1995-01-01  61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.8602
# 13              Haringey  E09000014 1995-01-01  76287.56947
# ...

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_long.dtypes
# Out:
# borough              object
# ID                   object
# date         datetime64[ns]
# avg_price            object
# dtype: object

# %%
print(type(properties_long['avg_price']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# convert avg_income values to float type

properties_long['avg_price'] = pd.to_numeric(properties_long['avg_price'],errors = 'coerce')

print(properties_long.dtypes)
# Out:
# borough              object
# ID                   object
# date         datetime64[ns]
# avg_price           float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
print(properties.shape)

#check for missing data
properties_long.count()
# Out:
# (322, 49)
# borough      10593
# ID           10593
# date         10593
# avg_price    10590
# dtype: int64

# %%
#investigate the NaNs in avg_income
properties_long[properties_long['avg_price'].isna()]
# Out:
#               borough         ID       date  avg_price
# 10494  City of London  E09000001 2021-07-01        NaN
# 10527  City of London  E09000001 2021-08-01        NaN
# 10560  City of London  E09000001 2021-09-01        NaN

# %%
# define new df without any na's 
properties_clean = properties_long.dropna()

#properties_clean.head(48)

# %%
print(properties_clean.shape)

#check for missing data
print(properties_clean.count())

print(properties_clean.head())
# Out:
# (10590, 4)
# borough      10590
# ID           10590
# date         10590
# avg_price    10590
# dtype: int64
#               borough         ID       date    avg_price
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
#add column for  just the 'year'   #### why the warning <-----???

from datetime import datetime
properties_clean['year'] = pd.DatetimeIndex(properties_clean['date']).year   #create new column 'year'
print(properties_clean.head())
# Out:
#               borough         ID       date    avg_price  year
# 0      City of London  E09000001 1995-01-01  91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660  1995
# 2              Barnet  E09000003 1995-01-01  93284.51832  1995
# 3              Bexley  E09000004 1995-01-01  64958.09036  1995
# 4               Brent  E09000005 1995-01-01  71306.56698  1995
# /var/folders/bv/4mctz8d94zx0nlh0hjsm4x8h0000gn/T/ipykernel_96160/45360937.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties_clean['year'] = pd.DatetimeIndex(properties_clean['date']).year   #create new column 'year'

# %%
#get avg income/year by borough

mean_inc_borough = properties_clean.groupby(["borough", 'year'])['avg_price'].mean()
#print(mean_inc_borough['Westminster'])
print(mean_inc_borough.head())
print(mean_inc_borough.shape)
print(type(mean_inc_borough))
# Out:
# borough             year
# Barking & Dagenham  1995    51817.969390
#                     1996    51718.192690
#                     1997    55974.262309
#                     1998    60285.821083
#                     1999    65320.934441
# Name: avg_price, dtype: float64
# (891,)
# <class 'pandas.core.series.Series'>

# %%
df = mean_inc_borough.reset_index()

# %%
df.head()
# Out:
#               borough  year     avg_price
# 0  Barking & Dagenham  1995  51817.969390
# 1  Barking & Dagenham  1996  51718.192690
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
import pandas as pd
for b, row in df.iterrows():
    print(b)
    print(row)
# Out:
# 0
# borough      Barking & Dagenham
# year                       1995
# avg_price           51817.96939
# Name: 0, dtype: object
# 1
# borough      Barking & Dagenham
# year                       1996
# avg_price           51718.19269
# Name: 1, dtype: object
# 2
# borough      Barking & Dagenham
# year                       1997
# avg_price          55974.262309
# Name: 2, dtype: object
# 3
# borough      Barking & Dagenham
# year                       1998
# avg_price          60285.821083
# Name: 3, dtype: object
# 4
# borough      Barking & Dagenham
# year                       1999
# avg_price          65320.934441
# Name: 4, dtype: object
# 5
# borough      Barking & Dagenham
# year                       2000
# avg_price           77549.51329
# Name: 5, dtype: object
# 6
# borough      Barking & Dagenham
# year                       2001
# avg_price          88664.058223
# Name: 6, dtype: object
# 7
# borough      Barking & Dagenham
# year                       2002
# ...

# %%
list_boroughs = df['borough'].unique()
        
for borough in list_boroughs:
        df_subset = df[df["borough"]==borough]
        df_subset.plot(x = 'year', y = 'avg_price', kind = 'line', title = (str(borough)))
        plt.show()

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
df.head()
# Out:
#               borough  year     avg_price
# 0  Barking & Dagenham  1995  51817.969390
# 1  Barking & Dagenham  1996  51718.192690
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %%
# price ratio function
def create_price_ratio(d):
    y1998 = float(d['avg_price'][d['year']==1998])
    y2018 = float(d['avg_price'][d['year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
create_price_ratio(df[df['borough']=='Barking & Dagenham'])
# Out:
# [4.89661861291754]

# %%
#empty dictionary to store ratios for each borough
final = {}

# %%
# loop iterate through each of the unique elements 'borough'
 
for b in df['borough'].unique():
    # parameter to create_price_ratio function: i.e., we subset dfg on 'London_Borough' == b. 
    bor = df[df['borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling create_price_ratio with the argument: borough
    final[b] = create_price_ratio(bor)
# We use the function and incorporate that into a new key of the dictionary 
print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.094784685333876], 'Camden': [4.935353408884261], 'City of London': [5.30162037758761], 'Croydon': [4.201100280024766], 'Ealing': [4.311450902121834], 'Enfield': [4.263471583495811], 'Greenwich': [4.7630363473291935], 'Hackney': [6.198285561008663], 'Hammersmith & Fulham': [4.13779810193623], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335307], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802297], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514062], 'Lewisham': [5.449221041059686], 'Merton': [4.741273313294603], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379378], 'Sutton': [4.11852260857
# ...

# %%
# dict to df. 
df_ratios = pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
# transpose it, and reset the index 
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
# rename the 'index' column as 'borough', and the '0' column to 'ratio'.
df_ratios.rename(columns={'index':'borough', 0:'ratio'}, inplace=True)
df_ratios.head()
# Out:
#               borough     ratio
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
# 15 most expensive boroughs

top15 = df_ratios.sort_values(by='ratio',ascending=False).head(15)
print(top15)
# Out:
#                  borough     ratio
# 11               Hackney  6.198286
# 30        Waltham Forest  5.834756
# 27             Southwark  5.516485
# 22              Lewisham  5.449221
# 32           Westminster  5.353565
# 24                Newham  5.305390
# 6         City of London  5.301620
# 13              Haringey  5.134625
# 19  Kensington & Chelsea  5.082465
# 21               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 18             Islington  4.844048
# 10             Greenwich  4.763036

# %%
# plot the boroughs that have seen the greatest changes in price.

ax = top15[['borough','ratio']].plot(kind='bar', color = 'green')

ax.set_xticklabels(top15.borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich')]

# %%
all_bors = df_ratios.sort_values(by='ratio',ascending=False)
#print(all)

# %%
# plot all boroughs.

al = all_bors[['borough','ratio']].plot(kind='bar', color = 'green')

al.set_xticklabels(all_bors.borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich'),
#  Text(15, 0, 'Wandsworth'),
#  Text(16, 0, 'Merton'),
#  Text(17, 0, 'Tower Hamlets'),
#  Text(18, 0, 'Redbridge'),
#  Text(19, 0, 'Barnet'),
#  Text(20, 0, 'Havering'),
#  Text(21, 0, 'Ealing'),
#  Text(22, 0, 'Kingston upon Thames'),
#  Text(23, 0, 'Enfield'),
#  Text(24, 0, 'Bexley'),
#  Text(25, 0, 'Croydon'),
#  Text(26, 0, 'Hillingdon'),
#  Text(27, 0, 'Hammersmith & Fulham'),
#  Text(28, 0, 'Sutton'),
#  Text(29, 0, 'Bromley'),
#  Text(30, 0, 'Harrow'),
#  Text(31, 0, 'Richmond upon Thames'),
#  Text(32, 0, 'Hounslow')]

# %%
df.describe()
# Out:
#               year     avg_price
# count   891.000000  8.910000e+02
# mean   2008.000000  3.142891e+05
# std       7.793256  2.087196e+05
# min    1995.000000  5.171819e+04
# 25%    2001.000000  1.709642e+05
# 50%    2008.000000  2.654480e+05
# 75%    2015.000000  4.100448e+05
# max    2021.000000  1.363880e+06

# %%
df.head()
# Out:
#               borough  year     avg_price
# 0  Barking & Dagenham  1995  51817.969390
# 1  Barking & Dagenham  1996  51718.192690
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %%
# price ratio function
def precov_price_ratio(p):
    y1998 = float(p['avg_price'][p['year']==1998])
    y2019 = float(p['avg_price'][p['year']==2019])
    ratio_p = [y2019/y1998]
    return ratio_p

# %%
precov_price_ratio(df[df['borough']=='Barking & Dagenham'])
# Out:
# [4.948724394015297]

# %%
#empty dictionary to store ratios for each borough
precov = {}

# %%
# loop iterate through each of the unique elements 'borough'
 
for b in df['borough'].unique():
    # parameter to covid_price_ratio function: i.e., we subset dfg on 'borough' == b. 
    bor = df[df['borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling covid_price_ratio with the argument: borough
    precov[b] = precov_price_ratio(bor)
# We use the function and incorporate that into a new key of the dictionary 
print(precov)
# Out:
# {'Barking & Dagenham': [4.948724394015297], 'Barnet': [4.254053774775033], 'Bexley': [4.179329969752098], 'Brent': [4.714664432793811], 'Bromley': [4.030844811160297], 'Camden': [4.939199743872227], 'City of London': [5.387386600328387], 'Croydon': [4.148683726047858], 'Ealing': [4.244718840318338], 'Enfield': [4.2209297955390035], 'Greenwich': [4.823560682246613], 'Hackney': [6.315422958173318], 'Hammersmith & Fulham': [4.100565467828577], 'Haringey': [5.084073297975735], 'Harrow': [3.9149151422910897], 'Havering': [4.259851201341958], 'Hillingdon': [4.140667359679945], 'Hounslow': [4.020932101318003], 'Islington': [4.72360312882345], 'Kensington & Chelsea': [4.626130833016595], 'Kingston upon Thames': [4.186671601660226], 'Lambeth': [4.924918811616125], 'Lewisham': [5.414648817779348], 'Merton': [4.678220823426442], 'Newham': [5.3788405020126575], 'Redbridge': [4.358784474596334], 'Richmond upon Thames': [3.985387511954901], 'Southwark': [5.463260537317313], 'Sutton': [4.0395854829
# ...

# %%
# price ratio function
def covid_price_ratio(c):
    y2020 = float(c['avg_price'][c['year']==2020])
    y2021 = float(c['avg_price'][c['year']==2021])
    ratio_c = [y2021/y2020]
    return ratio_c

# %%
covid_price_ratio(df[df['borough']=='Barking & Dagenham'])
# Out:
# [1.0498086943405878]

# %%
# dict to df. 
df_ratios_p = pd.DataFrame(precov)

# %%
df_ratios_p.head()
# Out:
#    Barking & Dagenham    Barnet   Bexley     Brent   Bromley  Camden  \
# 0            4.948724  4.254054  4.17933  4.714664  4.030845  4.9392
#
#    City of London   Croydon    Ealing  Enfield  ...    Merton    Newham  \
# 0        5.387387  4.148684  4.244719  4.22093  ...  4.678221  5.378841
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.358784              3.985388   5.463261  4.039585       4.541595
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.702082    4.692699     5.017524
#
# [1 rows x 33 columns]

# %%
# transpose it, and reset the index 
df_ratios_p_T = df_ratios_p.T
df_ratios_p = df_ratios_p_T.reset_index()
df_ratios_p.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.948724
# 1              Barnet  4.254054
# 2              Bexley  4.179330
# 3               Brent  4.714664
# 4             Bromley  4.030845

# %%
# rename the 'index' column as 'borough', and the '0' column to 'ratio_p'.
df_ratios_p.rename(columns={'index':'borough', 0:'ratio_p'}, inplace=True)
df_ratios_p.head()
# Out:
#               borough   ratio_p
# 0  Barking & Dagenham  4.948724
# 1              Barnet  4.254054
# 2              Bexley  4.179330
# 3               Brent  4.714664
# 4             Bromley  4.030845

# %%
#empty dictionary to store ratios for each borough
covid = {}

# %%
# loop iterate through each of the unique elements 'borough'
 
for b in df['borough'].unique():
    # parameter to covid_price_ratio function: i.e., we subset dfg on 'borough' == b. 
    bor = df[df['borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling covid_price_ratio with the argument: borough
    covid[b] = covid_price_ratio(bor)
# We use the function and incorporate that into a new key of the dictionary 
print(covid)
# Out:
# {'Barking & Dagenham': [1.0498086943405878], 'Barnet': [1.021315391740113], 'Bexley': [1.0625285513797083], 'Brent': [1.070047362896981], 'Bromley': [1.0698481779728042], 'Camden': [1.0134291114990375], 'City of London': [0.8798224450359772], 'Croydon': [1.0369792106198887], 'Ealing': [1.0630452984757273], 'Enfield': [1.0700728447662975], 'Greenwich': [1.0258115529293617], 'Hackney': [1.0289076185737283], 'Hammersmith & Fulham': [1.0482317745260195], 'Haringey': [1.057054347656633], 'Harrow': [1.0749079791220129], 'Havering': [1.0508557044832028], 'Hillingdon': [1.0512298658747077], 'Hounslow': [1.0444229846337176], 'Islington': [1.0264370902565738], 'Kensington & Chelsea': [0.9675965060631075], 'Kingston upon Thames': [1.0464023882901505], 'Lambeth': [1.0048676975959105], 'Lewisham': [1.0279561400179507], 'Merton': [1.0461427223957669], 'Newham': [1.0233031003347952], 'Redbridge': [1.0798451276794852], 'Richmond upon Thames': [1.0331780393097723], 'Southwark': [1.0236663283922047], 
# ...

# %%
# dict to df. 
df_ratios_c = pd.DataFrame(covid)

# %%
df_ratios_c.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            1.049809  1.021315  1.062529  1.070047  1.069848  1.013429
#
#    City of London   Croydon    Ealing   Enfield  ...    Merton    Newham  \
# 0        0.879822  1.036979  1.063045  1.070073  ...  1.046143  1.023303
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   1.079845              1.033178   1.023666  1.054463       0.977718
#
#    Waltham Forest  Wandsworth  Westminster
# 0        1.077701    0.984591     0.978859
#
# [1 rows x 33 columns]

# %%
# transpose it, and reset the index 
df_ratios_c_T = df_ratios_c.T
df_ratios_c = df_ratios_c_T.reset_index()
df_ratios_c.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  1.049809
# 1              Barnet  1.021315
# 2              Bexley  1.062529
# 3               Brent  1.070047
# 4             Bromley  1.069848

# %%
# rename the 'index' column as 'borough', and the '0' column to 'ratio'.
df_ratios_c.rename(columns={'index':'borough', 0:'ratio_c'}, inplace=True)
df_ratios_c.head()
# Out:
#               borough   ratio_c
# 0  Barking & Dagenham  1.049809
# 1              Barnet  1.021315
# 2              Bexley  1.062529
# 3               Brent  1.070047
# 4             Bromley  1.069848

# %%
list_pop_dicts = [{'Barking & Dagenham': 2, 'Barnet': 2, 'Bexley': 2, 'Brent': 3, 
                     'Bromley': 1, 'Camden': 4, 'City of London': 1, 
                     'Croydon': 2, 'Ealing': 3, 'Enfield': 2, 'Greenwich': 3, 'Hackney': 4, 
                     'Hammersmith & Fulham': 3, 'Haringey': 3, 'Harrow': 2, 'Havering': 1, 
                     'Hillingdon': 1, 'Hounslow': 2, 'Islington': 4, 'Kensington & Chelsea': 4, 
                     'Kingston upon Thames': 2, 'Lambeth': 4, 'Lewisham': 2, 'Merton': 2, 
                     'Newham': 3, 'Redbridge': 2, 'Richmond upon Thames': 1, 'Southwark': 3, 
                     'Sutton': 2, 'Tower Hamlets': 5, 'Waltham Forest': 3, 'Wandsworth': 4, 
                     'Westminster': 4}
                   ]

# %%
df_pop = pd.DataFrame(list_pop_dicts)

# %%
# transpose it, and reset the index 
df_pop_T = df_pop.T
df_pop = df_pop_T.reset_index()
df_pop.head()
# Out:
#                 index  0
# 0  Barking & Dagenham  2
# 1              Barnet  2
# 2              Bexley  2
# 3               Brent  3
# 4             Bromley  1

# %%
# rename the 'index' column as 'borough', and the '0' column to 'pop_dens'.
df_pop.rename(columns={'index':'borough', 0:'pop_dens'}, inplace=True)
df_pop.head()
# Out:
#               borough  pop_dens
# 0  Barking & Dagenham         2
# 1              Barnet         2
# 2              Bexley         2
# 3               Brent         3
# 4             Bromley         1

# %%
#merge df_ratios, df_ratios_c, df_pop on df['borough']
df_all = df_ratios_p.merge(df_ratios_c, on = 'borough')
df_all = df_all.merge(df_pop, on = 'borough')
print(df_all.head())
# Out:
#               borough   ratio_p   ratio_c  pop_dens
# 0  Barking & Dagenham  4.948724  1.049809         2
# 1              Barnet  4.254054  1.021315         2
# 2              Bexley  4.179330  1.062529         2
# 3               Brent  4.714664  1.070047         3
# 4             Bromley  4.030845  1.069848         1

# %%
# 15 most rising boroughs during pre-covid

top15_p = df_all.sort_values(by='ratio_p',ascending=False).head(15)
print(top15_p)
# Out:
#                borough   ratio_p   ratio_c  pop_dens
# 11             Hackney  6.315423  1.028908         4
# 30      Waltham Forest  5.702082  1.077701         3
# 27           Southwark  5.463261  1.023666         3
# 22            Lewisham  5.414649  1.027956         2
# 6       City of London  5.387387  0.879822         1
# 24              Newham  5.378841  1.023303         3
# 13            Haringey  5.084073  1.057054         3
# 32         Westminster  5.017524  0.978859         4
# 0   Barking & Dagenham  4.948724  1.049809         2
# 5               Camden  4.939200  1.013429         4
# 21             Lambeth  4.924919  1.004868         4
# 10           Greenwich  4.823561  1.025812         3
# 18           Islington  4.723603  1.026437         4
# 3                Brent  4.714664  1.070047         3
# 31          Wandsworth  4.692699  0.984591         4

# %%
# 15 most rising boroughs during covid

top15_c = df_all.sort_values(by='ratio_c',ascending=False).head(15)
print(top15_c)
# Out:
#                  borough     ratio   ratio_c  pop_dens
# 25             Redbridge  4.471182  1.079845         2
# 30        Waltham Forest  5.834756  1.077701         3
# 14                Harrow  4.059196  1.074908         2
# 9                Enfield  4.263472  1.070073         2
# 3                  Brent  4.894554  1.070047         3
# 4                Bromley  4.094785  1.069848         1
# 8                 Ealing  4.311451  1.063045         3
# 2                 Bexley  4.248977  1.062529         2
# 13              Haringey  5.134625  1.057054         3
# 28                Sutton  4.118523  1.054463         2
# 16            Hillingdon  4.200273  1.051230         1
# 15              Havering  4.325230  1.050856         1
# 0     Barking & Dagenham  4.896619  1.049809         2
# 12  Hammersmith & Fulham  4.137798  1.048232         3
# 20  Kingston upon Thames  4.270550  1.046402         2

# %%
#correlation matrix for price ratios and population density
df_all.corr()
# Out:
#            ratio_p   ratio_c  pop_dens
# ratio_p   1.000000 -0.344309  0.432226
# ratio_c  -0.344309  1.000000 -0.286293
# pop_dens  0.432226 -0.286293  1.000000

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %%
'''
The top 10 most expensive boroughs are: 
1. Hackney 
2. Waltham Forest
3. Southwark
4. Lewisham
5. Westminster
6. Newham
7. City of London
8. Haringsey
9. Kensington and Chelsea
10. Lambeth

A home in Hackney in 2018 was over six times the price of homes there in 1998. 
Home prices in Lambeth have incresed almost five times in the same period.

Home prices rose more in places with higher population density pre-covid. 
During the pandemic, in years 2020 and 2021, housing prices went from being positively correlated
with population density (r = 0.43) to being negatively correlated (r = -0.29) with population density, 
indicating people moved away from population centers and to less populated areas.

'''
